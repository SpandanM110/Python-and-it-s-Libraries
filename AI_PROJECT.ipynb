# %% [markdown]
# <a href="https://colab.research.google.com/github/SpandanM110/Python-and-it-s-Libraries/blob/main/AI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

print(x_train.shape)

print(x_test.shape)
# print(x_train[0])
print(x_train.ndim)
print(y_train[0])
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# 3
# 9

# %%
import cv2

#path = /content/e.jpeg'

img = cv2.imread('e.jpeg',1)

# cv2.imshow('Astronaut', img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.1.2

# %%
import cv2

image = cv2.imread('Astronaut.jpeg')
center_coordinates = (120, 50)
radius = 60
color = (255,0,0)
thickness = 30
image = cv2.circle(image,center_coordinates, radius, color, thickness)
# cv2.imshow("image",img)
# cv2.waitkey(0)
# cv2.destroyAllWindows
# print(image)

# %%
# Working Great!!!!
import cv2
from google.colab.patches import cv2_imshow

# path = r'C:\This PC\Desktop\Astronaut.jpeg'              ## Can also be done when you upload imge of file in the data or even by mentioning path

img = cv2.imread("Astronaut.jpeg",1)     # Syntax= cv2.imread(filename,[flags])
cv2_imshow(img)                          ## Flags<0    returns loaded image with aplha channel
                                         # Flags=0 gives grayscale  Flags>0 return 3 channel color image  
# cv2.waitkey(4)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1080x988 at 0x7F0289AB5C90>
