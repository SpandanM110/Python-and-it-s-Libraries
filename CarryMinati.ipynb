# %% [markdown]
# <a href="https://colab.research.google.com/github/SpandanM110/Python-and-it-s-Libraries/blob/main/CarryMinati.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project Printing CarryMinati
## NOTE FIRST WE NEED TO UPLOAD THE IMAGES


# Working Great!!!! 
import cv2
from google.colab.patches import cv2_imshow

# path = r'C:\This PC\Desktop\Astronaut.jpeg'              ## Can also be done when you upload imge of file in the data or even by mentioning path

img = cv2.imread("CarryMinati.png",12)     # Syntax= cv2.imread(filename,[flags])                   
cv2_imshow(img)                          ## Flags<0    returns loaded image with aplha channel
                                         # Flags=0 gives grayscale  Flags>0 return 3 channel color image and number changes size and color  
# cv2.waitkey(4)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGBA size=528x570 at 0x7F21523AB0D0>

# %%
from IPython.core.display import Image
#import of two libraries
import cv2
import numpy as np

#reading image
img = cv2.imread('Carry.png',1)

#Edges
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
edges = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 9, 9)

color = cv2.bilateralFilter(img, 9, 250, 250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

# cv2.imshow("Image", img)
# cv2.imshow("edges",edges)
# cv2.imshow("Cartoon",cartoon)


cv2_imshow(cartoon)
cv2_imshow(edges)
cv2_imshow(img)
# cv2.waitkey(0)
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=260x351 at 0x7F214EAB3350>
# <PIL.Image.Image image mode=L size=260x351 at 0x7F214EAB3A90>
# <PIL.Image.Image image mode=RGB size=260x351 at 0x7F214EAB3350>
